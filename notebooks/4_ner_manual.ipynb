# %% [markdown]
# ## 4_NER_manual

# %% [markdown]
# In addition to NER by spaCy(3_ner notebook), for Job titles (JOB), industries (IND), and technology names (TECH) that are difficult to recognize with default spaCy, lists were manually created utilizing websites and GPT-4, and recognition was simplified using regular expressions.

# %%
import pandas as pd
import re
from tqdm import tqdm
from collections import Counter

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 500)

import warnings
warnings.simplefilter('ignore')
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# %%time

df = pd.read_parquet('sentence.parquet', engine='pyarrow')
df.shape
# Out:
# CPU times: user 2.62 s, sys: 2.25 s, total: 4.87 s
# Wall time: 5.54 s
# (7068447, 3)

# %%
df.head()
# Out:
#    doc_id  sentence_id  \
# 0       1            1
# 1       1            2
# 2       1            3
# 3       1            4
# 4       1            5
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               sentence
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                        LegalTech Artificial Intelligence Market 2019
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                Technology Advancement and Future Scope Casetext Inc.
# 2  Catalyst Repository Systems eBREVIA Galus Australis Galus Australis BusinessGeneral NewsHealthcareIndustryInternationalLifestyleSci-Tech Wednesday February 26 2020 Trending Needle Counters Market Comprehensive Study by Companies Medline Industries Boen Healthcare Skin Scrub Trays Market Comprehensive Study by Companies Medline Industries BD Deroyal Global Portable Handheld Electronic Game Machine Market Outlook and Business Insights 2020-2026 Apollo Games Sony Aristocrat Leisure IGT Infectio...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Catalyst Repository Systems eBREVIA
# 4                                                                                                                                                                                                                                                                                                                                                                                                      General NewsLegalTech Artificial Intelligence Market 2019 Technology Advancement and Future Scope Casetext Inc.

# %% [markdown]
# ## Industry

# %%
# industry list
industry = pd.read_csv('Industry.csv')

# %%
industry
# Out:
#                      Industry
# 0                   Aerospace
# 1                 Agriculture
# 2                     Airline
# 3                     Apparel
# 4                  Automotive
# 5                     Biotech
# 6               Biotechnology
# 7                    Chemical
# 8       Communication Service
# 9                Construction
# 10                 Consulting
# 11                   Consumer
# 12                    Defense
# 13                 E commerce
# 14                 E-commerce
# 15                  Education
# 16                     Energy
# 17                Engineering
# 18              Entertainment
# 19                    Finance
# 20                  Financial
# 21                    Fintech
# 22                       Bank
# 23          Food and Beverage
# 24                       Game
# 25                     Gaming
# 26                   Hardware
# 27                Health Care
# 28                 Healthcare
# 29                      Hotel
# 30                 Industrial
# 31     Information Technology
# 32                  Insurance
# 33                        Law
# 34                      Legal
# 35                    Leisure
# 36                  Logistics
# 37              Manufacturing
# 38                   Material
# 39                      Metal
# 40                     Mining
# 41             Pharmaceutical
# 42                Real Estate
# 43                 Restaurant
# 44                     Retail
# 45              Semiconductor
# 46                   Software
# 47          Telecommunication
# 48             Transportation
# 49                 Publishing
# 50           Renewable Energy
# 51                   Robotics
# 52          Safety & Security
# 53                   Shipping
# 54               Social Media
# 55  Social Networking Service
# 56                     Sports
# 57                    Tourism
# 58                  Utilities
# 59           Waste Management
# 60            Water Resources
# 61               Web Services
# 62                  Wholesale
# 63                 Blockchain
# 64            Cloud Computing
# 65              Cybersecurity
# 66          Digital Marketing
# 67                 E-Learning
# 68     Environmental Services
# 69           Event Management
# 70                    Fashion
# 71            Film Production
# 72             Graphic Design
# 73            Home Appliances
# 74                 Journalism
# 75                   Maritime
# 76           Music Production
# 77                        NPO
# 78                        NGO
# 79    Non-Profit Organization
# 80                 University
# 81                 Government
# 82                     School
# 83              Personal Care
# 84                   Pet Care
# 85                        Art
# 86           Public Relations
# 87    Real Estate Development
# 88     Research & Development
# 89   Research and Development
# 90          Retail Technology
# 91        Safety and Security
# 92          Social Networking
# 93       Software Development
# 94               Solar Energy
# 95           Sports Equipment
# 96                   Textiles
# 97            Travel Services
# 98                Video Games

# %% [markdown]
# ## Job Title

# %%
#  job title list
job = pd.read_csv('JobTitle.csv')

# %%
job
# Out:
#                                 job
# 0                          Engineer
# 1                 Account Executive
# 2                        Copywriter
# 3                  Graphic Designer
# 4           Market Research Analyst
# 5                   Product Manager
# 6           Agricultural Specialist
# 7                        Biochemist
# 8               Biomedical Engineer
# 9              Research Coordinator
# 10                   Microbiologist
# 11                        Architect
# 12                   Civil Engineer
# 13             Construction Manager
# 14                         Surveyor
# 15                         Educator
# 16                   Energy Analyst
# 17                           Artist
# 18                Financial Analyst
# 19             Food Service Manager
# 20           Public Service Officer
# 21          Healthcare Professional
# 22                Event Coordinator
# 23              Industrial Engineer
# 24                Logistics Manager
# 25               Media Professional
# 26                        Geologist
# 27               Research Associate
# 28             Pharmaceutical Sales
# 29     Quality Assurance Specialist
# 30         Real Estate Professional
# 31                   Retail Manager
# 32         Cybersecurity Specialist
# 33                 Network Engineer
# 34               Software Developer
# 35                    Web Developer
# 36           Transportation Manager
# 37         Environmental Specialist
# 38                     Veterinarian
# 39                        Zoologist
# 40                 Business Manager
# 41               Salon Professional
# 42  Customer Service Representative
# 43                     Art Director
# 44                          Teacher
# 45                         Lecturer
# 46                        Professor
# 47                        Librarian
# 48                Chemical Engineer
# 49                Financial Adviser
# 50                        Caregiver
# 51              Dental Professional
# 52              Hospitality Manager
# 53          Human Resources Manager
# 54                         Designer
# 55                  IT Professional
# 56               Operations Manager
# 57           Marketing Professional
# 58                 Media Specialist
# 59                        Scientist
# 60                          Athlete
# 61             Fitness Professional
# 62              Computer Specialist
# 63                          Artisan
# 64                        Carpenter
# 65                     AI Developer
# 66                   Data Scientist
# 67        Machine Learning Engineer
# 68                     Data Analyst
# 69                    Data Engineer
# 70               Research Scientist
# 71                           Writer
# 72                          Analyst
# 73                Energy Specialist
# 74           Financial Professional
# 75                             Chef
# 76                     Nutritionist
# 77                  Service Manager
# 78                     City Planner
# 79                    Hotel Manager
# 80               Tourism Specialist
# 81           Logistics Professional
# 82   Quality Assurance Professional
# 83                           Editor
# 84               Sales Professional
# 85              Retail Professional
# 86       Cybersecurity Professional
# 87             Network Professional
# 88            Software Professional
# 89                        Physicist
# 90      Transportation Professional
# 91                Animal Specialist
# 92                  Project Manager
# 93            Business Professional
# 94                Care Professional
# 95         Hospitality Professional
# 96     Human Resources Professional
# 97                Software Engineer
# 98                   Media Producer
# 99              Sports Professional

# %% [markdown]
# ## Technology

# %%
# technology list
tech = pd.read_csv('Technology.csv')

# %%
tech
# Out:
#                           technology
# 0                              GenAI
# 1                             Gen AI
# 2                      Generative AI
# 3                                GPT
# 4                             GPT3.5
# 5                            GPT-3.5
# 6                               GPT4
# 7                              GPT-4
# 8                            ChatGPT
# 9                                LLM
# 10                              LLMs
# 11                       Transformer
# 12                              BERT
# 13                              PaLM
# 14                             LLaMA
# 15                             Cloud
# 16                               GPU
# 17                  Machine Learning
# 18                                ML
# 19                     Deep Learning
# 20            Reinforcement Learning
# 21                 Transfer Learning
# 22                              Bard
# 23                           ‎Gemini
# 24                 Conversational AI
# 25                               NLP
# 26       Natural Language Processing
# 27                    Edge Computing
# 28                               HPC
# 29        High-performance computing
# 30        High performance computing
# 31                              Bing
# 32                               CRM
# 33         Security Operation Center
# 34                               SOC
# 35                         Galaxy AI
# 36                                EV
# 37                         AI Ethics
# 38                     AI Governance
# 39                            AutoML
# 40                       AI for Good
# 41                 Quantum Computing
# 42          Quantum Machine Learning
# 43                Federated Learning
# 44                    Synthetic Data
# 45          Robot Process Automation
# 46       Natural Language Generation
# 47                   Computer Vision
# 48                 Image Recognition
# 49                Speech Recognition
# 50                  Voice Assistants
# 51                      Semantic Web
# 52                  Knowledge Graphs
# 53                 Augmented Reality
# 54                   Virtual Reality
# 55                        Blockchain
# 56                     Cybersecurity
# 57                     Digital Twins
# 58                Internet of Things
# 59                          Big Data
# 60                                AR
# 61                                VR
# 62                               RPA
# 63                               NLG
# 64                               IoT
# 65                        TensorFlow
# 66                     SoundHound AI
# 67                            OpenAI
# 68                             GPT-3
# 69                            DALL·E
# 70                             DALLE
# 71                             Codex
# 72                              Clip
# 73                          DeepMind
# 74                               VAE
# 75                               GAN
# 76   Generative Adversarial Networks
# 77                  Diffusion Models
# 78                                T5
# 79                             XLNet
# 80                           ELECTRA
# 81                           RoBERTa
# 82                         AI21 Labs
# 83                  Stable Diffusion
# 84                        Midjourney
# 85                       Fine Tuning
# 86                  Model Adaptation
# 87                Pre-trained Models
# 88                     Custom Models
# 89                  Model Retraining
# 90             Hyperparameter Tuning
# 91            Knowledge Distillation
# 92                Feature Extraction
# 93                   Embedding Layer
# 94                 Vector Embeddings
# 95                   Semantic Search
# 96      Approximate Nearest Neighbor
# 97                   Vector Database
# 98                   Vector Indexing
# 99              Vector Search Engine
# 100                            Faiss
# 101                            Annoy
# 102                    Elasticsearch
# 103                         Pinecone
# 104                           Milvus
# 105                         Weaviate
# 106                             HNSW
# 107                            ScaNN
# 108                              IVF
# 109                     Quantization
# 110            Vector Space Modeling
# 111         Dimensionality Reduction
# 112                            t-SNE
# 113                             UMAP
# 114                              ANN
# 115                    Vector Search
# 116                             Sora
# 117                          Chatbot
# 118                 Image Generation

# %% [markdown]
# ## Add Entities

# %%
# %%time

# Add manual entities in the same format as NER

# Define a function to detect if keywords are present in a sentence, converting both to lowercase. 
# Accepts an entity type as an argument to generalize its use.
def find_keywords(sentence, keywords, entity_type):
    sentence_lower = sentence.lower()
    return [[keyword, entity_type] for keyword in keywords if re.search(r'\b{}\b'.format(re.escape(keyword.lower())), sentence_lower)]

# Create lists of keywords for industries, jobs, and technologies.
industry_keywords = industry['Industry'].tolist()
job_keywords = job['job'].tolist()
tech_keywords = tech['technology'].tolist()

# Search for matching keywords in all sentences for each category.
entities_ind = [find_keywords(sentence, industry_keywords, 'IND') for sentence in df['sentence']]
entities_job = [find_keywords(sentence, job_keywords, 'JOB') for sentence in df['sentence']]
entities_tech = [find_keywords(sentence, tech_keywords, 'TECH') for sentence in df['sentence']]

# Add new columns to the DataFrame for each entity type.
df['entities_ind'] = entities_ind
df['entities_job'] = entities_job
df['entities_tech'] = entities_tech
# Out:
# CPU times: user 1h 50min 58s, sys: 21.4 s, total: 1h 51min 19s
# Wall time: 1h 51min 33s

# %% [markdown]
# ## Result

# %%
# Show 5 rows that has new entities
df[(df['entities_ind'].apply(lambda x: len(x) > 0)) & (df['entities_job'].apply(lambda x: len(x) > 0)) & (df['entities_tech'].apply(lambda x: len(x) > 0))].head()
# Out:
#       doc_id  sentence_id  \
# 4527      94            1
# 4698      98            2
# 5636     116            6
# 5644     116           14
# 6108     125           22
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  sentence  \
# 4527  Microsoft's new AI key is first big change to keyboards in decades - KESQ circle-arrow Play Button Stop Button chevron-right chevron-left chevron-up search warning chevron-left-skinny chevron-right-skinny x clock calendar play-button cancel-circle user twitter facebook youtube instagram email linkedin Home News California Crime Colorado River Crisis Coachella Valley Questions Answered Education Fentanyl Crisis Palm Springs International Film Festival I-Team Investigations Neighborhood Heroes...
# 4698  Viaero Wireless Network Cameras Weather Video Ski Report Weather Photo Galleries Sports Friday Night Blitz Videos and Livestream Live Newscasts Livestream Special Coverage Videos Radio KRDO NewsRadio Traffic Weather Maps and Forecasts Listen Live Radio Program Guide Podcasts Radio Contests Pet of the Week Traffic Gas Prices Health Healthy Colorado Healthy Kids Healthy Seniors Healthy Women Healthy Men Centura Health Telemundo Telemundo Programacion Colorado Living Victory For Veterans Events...
# 5636                                                                                                                        Artisan 9 Automotive 198 Best Gear 6 Bicycles 20 Books 3 BrandingIdentity 254 Camping 32 Climate Change 807 Clothing 70 Colors 918 Craft 305 Culture 57 Design 2214 Documentary Film 809 Dogs 50 Drink 99 Eco-Friendly 298 Europe 18 EV 60 Family 30 Fashion 154 Flowers 46 Food 310 Footwear 45 Furniture 231 Future 995 Get Smarter 891 Gifts 2 Gluten-Free 9 Graphic Design 63 History 271
# 5644                                                                                                                        Artisan 9 Automotive 198 Best Gear 6 Bicycles 20 Books 3 BrandingIdentity 254 Camping 32 Climate Change 807 Clothing 70 Colors 918 Craft 305 Culture 57 Design 2214 Documentary Film 809 Dogs 50 Drink 99 Eco-Friendly 298 Europe 18 EV 60 Family 30 Fashion 154 Flowers 46 Food 310 Footwear 45 Furniture 231 Future 995 Get Smarter 891 Gifts 2 Gluten-Free 9 Graphic Design 63 History 271
# 6108  For the last few years Seattle-based software engineer Peter Whidden has been training a reinforcement learning algorithm to navigate the classic first game of the Pokmon series -- in that time the AI has played more than 50000 hours of the game.11h agoTechCrunchTrans healthcare startup Plume lays off dozens of workersPlume a startup founded to offer essential online healthcare services to trans people across the U.S. laid off more than two dozen workers in October several sources close to t...
#
#                                                     entities_ind  \
# 4527            [[Education, IND], [Sports, IND], [School, IND]]
# 4698                       [[Entertainment, IND], [Sports, IND]]
# 5636  [[Automotive, IND], [Fashion, IND], [Graphic Design, IND]]
# 5644  [[Automotive, IND], [Fashion, IND], [Graphic Design, IND]]
# 6108           [[Game, IND], [Healthcare, IND], [Software, IND]]
#
#                                      entities_job  \
# 4527                             [[Athlete, JOB]]
# 4698                              [[Writer, JOB]]
# 5636                             [[Artisan, JOB]]
# 5644                             [[Artisan, JOB]]
# 6108  [[Engineer, JOB], [Software Engineer, JOB]]
#
#                          entities_tech
# 4527                    [[PaLM, TECH]]
# 4698                 [[ChatGPT, TECH]]
# 5636                      [[EV, TECH]]
# 5644                      [[EV, TECH]]
# 6108  [[Reinforcement Learning, TECH]]

# %%
# Merge 3 entities columns to 'entities_manual'
df['entities_manual'] = df.apply(lambda row: row['entities_ind'] + row['entities_job'] + row['entities_tech'], axis=1)

# %%
# Count entities

# function
# Count entities by type and return a DataFrame showing the top N entities for each specified type
def count_top_entities(entities_series, entity_types, top_n):
    counters = {entity_type: Counter() for entity_type in entity_types}
    
    # Iterate over the series to count entities by type
    for entities in entities_series:
        for entity_text, entity_type in entities:
            if entity_type in entity_types:
                counters[entity_type][entity_text] += 1
    
    # Prepare the DataFrame to display the top N entities for each type, filling in missing values
    top_entities_df = pd.DataFrame()
    for entity_type in entity_types:
        top_entities = counters[entity_type].most_common(top_n)
        # Ensure the list has a length of top_n by appending empty strings if necessary
        top_entities += [("", 0)] * (top_n - len(top_entities))
        top_entities_df[entity_type] = [f"{entity[0]} ({entity[1]})" if entity[0] else "" for entity in top_entities]
    
    return top_entities_df

# %%
# Count entities by type
entity_types = ['IND', 'JOB', 'TECH']
top_n = 50

top_entities_df = count_top_entities(df['entities_manual'], entity_types, top_n)
top_entities_df
# Out:
#                        IND                                   JOB  \
# 0        Software (141933)                        Editor (19206)
# 1       Financial (100247)                       Analyst (18475)
# 2           Sports (97024)                     Professor (18091)
# 3       Healthcare (82139)                        Artist (10537)
# 4    Entertainment (81627)                        Writer (10364)
# 5        Education (72731)                     Scientist (10298)
# 6       Government (71007)                        Athlete (7505)
# 7           Energy (70648)                       Engineer (7177)
# 8           School (62584)                        Teacher (5819)
# 9         Consumer (54250)                       Designer (4082)
# 10            Game (51962)                      Architect (1842)
# 11    Social Media (50734)                           Chef (1802)
# 12      University (50049)                 Data Scientist (1635)
# 13             Law (49557)                Product Manager (1259)
# 14           Legal (48051)                       Educator (1142)
# 15       Insurance (47434)              Software Engineer (1051)
# 16   Manufacturing (43786)                    AI Developer (858)
# 17             Art (43397)                        Lecturer (771)
# 18         Finance (43224)              Research Scientist (751)
# 19          Retail (40129)              Software Developer (676)
# 20          Gaming (36171)                       Physicist (542)
# 21      Automotive (33967)                       Caregiver (448)
# 22        Hardware (32980)               Financial Adviser (282)
# 23     Engineering (32175)               Financial Analyst (273)
# 24     Real Estate (28948)                 Project Manager (260)
# 25   Cybersecurity (28731)                      Copywriter (226)
# 26         Defense (27332)                       Carpenter (204)
# 27      Industrial (26295)                    Data Analyst (203)
# 28            Bank (26192)       Machine Learning Engineer (198)
# 29  Transportation (24120)                    Veterinarian (192)
# 30        Material (23563)              Research Associate (173)
# 31      Blockchain (23070)              Operations Manager (159)
# 32        Robotics (21705)                         Artisan (151)
# 33      Publishing (20990)          Financial Professional (148)
# 34         Fashion (20249)                       Librarian (122)
# 35    Construction (19303)                    Art Director (103)
# 36     Agriculture (17342)                    Data Engineer (98)
# 37      Consulting (15423)                 Graphic Designer (96)
# 38     Health Care (14169)                    Web Developer (94)
# 39          Mining (12541)                Account Executive (92)
# 40       Aerospace (12516)                   Media Producer (89)
# 41       Logistics (11911)                     Nutritionist (82)
# 42   Semiconductor (11179)          Healthcare Professional (77)
# 43         Fintech (10756)                 Business Manager (72)
# 44      E-commerce (10339)         Cybersecurity Specialist (71)
# 45      Journalism (10205)  Customer Service Representative (62)
# 46          Tourism (8880)                  IT Professional (50)
# 47  Cloud Computing (8716)            Business Professional (37)
# 48        Utilities (8647)                  Service Manager (36)
# 49         Chemical (8629)           Marketing Professional (35)
#
#                                    TECH
# 0                Generative AI (136466)
# 1                        Cloud (131637)
# 2                      ChatGPT (104579)
# 3              Machine Learning (71834)
# 4                        OpenAI (59404)
# 5                       Chatbot (44835)
# 6                 Cybersecurity (28731)
# 7                           GPT (27349)
# 8                    Blockchain (23070)
# 9                          Bard (22362)
# 10                           ML (21886)
# 11              Computer Vision (17972)
# 12                         Bing (17949)
# 13                          IoT (16920)
# 14                Deep Learning (16723)
# 15            Conversational AI (16664)
# 16                     Big Data (12842)
# 17  Natural Language Processing (12088)
# 18                         LLMs (11320)
# 19                          GPU (11080)
# 20                        GPT-4 (10892)
# 21                           LLM (9769)
# 22                           NLP (7817)
# 23                            AR (7377)
# 24                            EV (6391)
# 25                      DeepMind (6235)
# 26            Internet of Things (5977)
# 27                         GenAI (5956)
# 28                           CRM (5542)
# 29                         GPT-3 (5403)
# 30                        Gen AI (5309)
# 31                            VR (5263)
# 32                    Midjourney (5199)
# 33              Stable Diffusion (4615)
# 34                 AI Governance (4521)
# 35                Edge Computing (4286)
# 36                          PaLM (4192)
# 37                           HPC (4134)
# 38             Augmented Reality (3727)
# 39                           SOC (3664)
# 40               Virtual Reality (3602)
# 41                     AI Ethics (3579)
# 42             Quantum Computing (3533)
# 43                         LLaMA (3528)
# 44            Speech Recognition (3251)
# 45                 SoundHound AI (3207)
# 46             Image Recognition (3072)
# 47                Synthetic Data (2767)
# 48        Reinforcement Learning (2443)
# 49                   Transformer (2251)

# %%
# Save

df_drop = df[['doc_id','sentence_id', 'entities_manual']]

# Specify the file path where the Parquet file will be saved
file_path = 'entities_manual.parquet'
# Save the DataFrame as a Parquet file
df_drop.to_parquet(file_path)

# %% [markdown]
# Note: In the final analysis, topics labeled as 'other' have been excluded, which has resulted in different rankings for entities (refer to the 6_summary file). A detailed analysis of each entity will be presented in the 6_summary file.
